# %%
# Import basic liabraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
# Load the data
X_train = pd.read_csv('X_train_no_miss.csv')
y_train = pd.read_csv('Y_train.csv')
X_test = pd.read_csv('X_test_no_miss.csv')

# %%
X_train.columns
# Out:
# Index(['ID', 'Gender', 'Customer_Type', 'Age', 'Type_Travel', 'Travel_Class',
#        'Travel_Distance', 'Departure_Delay_in_Mins', 'Arrival_Delay_in_Mins',
#        'Seat_Comfort', 'Seat_Class', 'Arrival_Time_Convenient', 'Catering',
#        'Platform_Location', 'Onboard_Wifi_Service', 'Onboard_Entertainment',
#        'Online_Support', 'Ease_of_Online_Booking', 'Onboard_Service',
#        'Legroom', 'Baggage_Handling', 'CheckIn_Service', 'Cleanliness',
#        'Online_Boarding'],
#       dtype='object')

# %%
from sklearn.preprocessing import PolynomialFeatures

def create_interaction_features(df, selected_columns):
    """
    Function to add interaction features to the dataset, allowing dynamic column selection.
    
    Args:
    df (pd.DataFrame): Input DataFrame containing the features.
    selected_columns (list): List of column names for which to create interaction terms.
    
    Returns:
    pd.DataFrame: DataFrame with the original and new interaction features.
    """
    # Initialize PolynomialFeatures object to create interaction terms
    # Only interaction terms, no quadratic terms (degree=2 and interaction_only=True)
    poly = PolynomialFeatures(degree=2, interaction_only=True, include_bias=False)
    
    # Fit and transform the selected columns to create interaction features
    interactions = poly.fit_transform(df[selected_columns])
    
    # Create feature names for the interactions using get_feature_names_out for compatibility with newer sklearn
    interaction_features = poly.get_feature_names_out(selected_columns)
    
    # Remove original feature names from the list as they are included in the DataFrame already
    interaction_features = interaction_features[len(selected_columns):]
    
    # Convert the generated array from PolynomialFeatures into a DataFrame
    interaction_df = pd.DataFrame(interactions[:, len(selected_columns):], columns=interaction_features, index=df.index)
    
    # Concatenate the original DataFrame with the new interaction features DataFrame
    new_df = pd.concat([df, interaction_df], axis=1)
    
    return new_df

# %%
# Consider: 'Travel_Distance', 'Departure_Delay_in_Mins', 'Arrival_Delay_in_Mins'
A = ['Travel_Distance', 'Departure_Delay_in_Mins', 'Arrival_Delay_in_Mins']
train_data_A = create_interaction_features(X_train, A)
test_data_A = create_interaction_features(X_test, A)

# %%
# Consider: 'Online_Support', 'Ease_of_Online_Booking', 'Onboard_Service', 'Online_Boarding'
B = ['Online_Support', 'Ease_of_Online_Booking', 'Onboard_Service', 'Online_Boarding']
train_data_AB = create_interaction_features(train_data_A, B)
test_data_AB = create_interaction_features(test_data_A, B)

# %%
train_data_AB
# Out:
#              ID  Gender  Customer_Type   Age  Type_Travel  Travel_Class  \
# 0      98800001     0.0            1.0  52.0          0.0             0
# 1      98800002     1.0            1.0  48.0          1.0             1
# 2      98800003     0.0            1.0  43.0          0.0             0
# 3      98800004     0.0            1.0  44.0          0.0             0
# 4      98800005     0.0            1.0  50.0          0.0             0
# ...         ...     ...            ...   ...          ...           ...
# 94374  98894375     1.0            1.0  32.0          0.0             0
# 94375  98894376     1.0            1.0  44.0          0.0             0
# 94376  98894377     1.0            1.0  63.0          0.0             0
# 94377  98894378     1.0            1.0  16.0          1.0             1
# 94378  98894379     1.0            1.0  54.0          0.0             1
#
#        Travel_Distance  Departure_Delay_in_Mins  Arrival_Delay_in_Mins  \
# 0                  272                      0.0                    5.0
# 1                 2200                      9.0                    0.0
# 2                 1061                     77.0                  119.0
# 3                  780                     13.0                   18.0
# 4                 1981                      0.0                    0.0
# ...                ...                      ...                    ...
# 94374             1357                     83.0                  125.0
# 94375              592                      5.0                   11.0
# 94376             2794                      0.0                    0.0
# 94377             2744                      0.0                    0.0
# 94378             2107                     28.0                   28.0
#
#        Seat_Comfort  ...  Online_Boarding  \
# 0               2.0  ...              1.0
# 1               1.0  ...              4.0
# 2               2.0  ...              5.0
# 3               3.0  ...              3.0
# 4               3.0  ...              4.0
# ...             ...  ...              ...
# 94374           1.0  ...              1.0
# 94375           4.0  ...              4.0
# 94376           2.0  ...              3.0
# 94377           2.0  ...              4.0
# 94378           3.0  ...              3.0
#
#        Travel_Distance Departure_Delay_in_Mins  \
# 0                                          0.0
# 1                                      19800.0
# 2                                      81697.0
# 3                                      10140.0
# 4                                          0.0
# ...                                        ...
# 94374                                 112631.0
# 94375                                   2960.0
# 94376                                      0.0
# 94377                                      0.0
# 94378                                  58996.0
#
#        Travel_Distance Arrival_Delay_in_Mins  \
# 0                                     1360.0
# 1                                        0.0
# 2                                   126259.0
# 3                                    14040.0
# 4                                        0.0
# ...                                      ...
# 94374                               169625.0
# 94375                                 6512.0
# 94376                                    0.0
# 94377                                    0.0
# 94378                                58996.0
#
#        Departure_Delay_in_Mins Arrival_Delay_in_Mins  \
# 0                                                0.0
# 1                                                0.0
# 2                                             9163.0
# 3                                              234.0
# 4                                                0.0
# ...                                              ...
# 94374                                        10375.0
# 94375                                           55.0
# 94376                                            0.0
# 94377                                            0.0
# 94378                                          784.0
#
#        Online_Support Ease_of_Online_Booking  Online_Support Onboard_Service  \
# 0                                        6.0                             6.0
# 1                                       16.0                            20.0
# 2                                       25.0                            25.0
# 3                                        9.0                             9.0
# 4                                       20.0                            20.0
# ...                                      ...                             ...
# 94374                                    1.0                             4.0
# 94375                                   15.0                            15.0
# 94376                                   16.0                            16.0
# 94377                                   16.0                            12.0
# 94378                                    9.0                             3.0
#
#        Online_Support Online_Boarding  Ease_of_Online_Booking Onboard_Service  \
# 0                                 3.0                                     4.0
# 1                                16.0                                    20.0
# 2                                25.0                                    25.0
# 3                                 9.0                                     9.0
# 4                                20.0                                    16.0
# ...                               ...                                     ...
# 94374                             1.0                                     4.0
# 94375                            20.0                                     9.0
# 94376                            12.0                                    16.0
# 94377                            16.0                                    12.0
# 94378                             9.0                                     3.0
#
#        Ease_of_Online_Booking Online_Boarding  Onboard_Service Online_Boarding
# 0                                         2.0                              2.0
# 1                                        16.0                             20.0
# 2                                        25.0                             25.0
# 3                                         9.0                              9.0
# 4                                        16.0                             16.0
# ...                                       ...                              ...
# 94374                                     1.0                              4.0
# 94375                                    12.0                             12.0
# 94376                                    12.0                             12.0
# 94377                                    16.0                             12.0
# 94378                                     9.0                              3.0
#
# [94379 rows x 33 columns]

# %%
# Consider: 'Seat_Comfort', 'Seat_Class', 'Legroom'
C = ['Seat_Comfort', 'Seat_Class', 'Legroom']
train_data_ABC = create_interaction_features(train_data_AB, C)
test_data_ABC = create_interaction_features(test_data_AB, C)

# %%
train_data_ABC
# Out:
#              ID  Gender  Customer_Type   Age  Type_Travel  Travel_Class  \
# 0      98800001     0.0            1.0  52.0          0.0             0
# 1      98800002     1.0            1.0  48.0          1.0             1
# 2      98800003     0.0            1.0  43.0          0.0             0
# 3      98800004     0.0            1.0  44.0          0.0             0
# 4      98800005     0.0            1.0  50.0          0.0             0
# ...         ...     ...            ...   ...          ...           ...
# 94374  98894375     1.0            1.0  32.0          0.0             0
# 94375  98894376     1.0            1.0  44.0          0.0             0
# 94376  98894377     1.0            1.0  63.0          0.0             0
# 94377  98894378     1.0            1.0  16.0          1.0             1
# 94378  98894379     1.0            1.0  54.0          0.0             1
#
#        Travel_Distance  Departure_Delay_in_Mins  Arrival_Delay_in_Mins  \
# 0                  272                      0.0                    5.0
# 1                 2200                      9.0                    0.0
# 2                 1061                     77.0                  119.0
# 3                  780                     13.0                   18.0
# 4                 1981                      0.0                    0.0
# ...                ...                      ...                    ...
# 94374             1357                     83.0                  125.0
# 94375              592                      5.0                   11.0
# 94376             2794                      0.0                    0.0
# 94377             2744                      0.0                    0.0
# 94378             2107                     28.0                   28.0
#
#        Seat_Comfort  ...  Departure_Delay_in_Mins Arrival_Delay_in_Mins  \
# 0               2.0  ...                                            0.0
# 1               1.0  ...                                            0.0
# 2               2.0  ...                                         9163.0
# 3               3.0  ...                                          234.0
# 4               3.0  ...                                            0.0
# ...             ...  ...                                            ...
# 94374           1.0  ...                                        10375.0
# 94375           4.0  ...                                           55.0
# 94376           2.0  ...                                            0.0
# 94377           2.0  ...                                            0.0
# 94378           3.0  ...                                          784.0
#
#        Online_Support Ease_of_Online_Booking  Online_Support Onboard_Service  \
# 0                                        6.0                             6.0
# 1                                       16.0                            20.0
# 2                                       25.0                            25.0
# 3                                        9.0                             9.0
# 4                                       20.0                            20.0
# ...                                      ...                             ...
# 94374                                    1.0                             4.0
# 94375                                   15.0                            15.0
# 94376                                   16.0                            16.0
# 94377                                   16.0                            12.0
# 94378                                    9.0                             3.0
#
#        Online_Support Online_Boarding  Ease_of_Online_Booking Onboard_Service  \
# 0                                 3.0                                     4.0
# 1                                16.0                                    20.0
# 2                                25.0                                    25.0
# 3                                 9.0                                     9.0
# 4                                20.0                                    16.0
# ...                               ...                                     ...
# 94374                             1.0                                     4.0
# 94375                            20.0                                     9.0
# 94376                            12.0                                    16.0
# 94377                            16.0                                    12.0
# 94378                             9.0                                     3.0
#
#        Ease_of_Online_Booking Online_Boarding  \
# 0                                         2.0
# 1                                        16.0
# 2                                        25.0
# 3                                         9.0
# 4                                        16.0
# ...                                       ...
# 94374                                     1.0
# 94375                                    12.0
# 94376                                    12.0
# 94377                                    16.0
# 94378                                     9.0
#
#        Onboard_Service Online_Boarding  Seat_Comfort Seat_Class  \
# 0                                  2.0                      0.0
# 1                                 20.0                      1.0
# 2                                 25.0                      0.0
# 3                                  9.0                      3.0
# 4                                 16.0                      3.0
# ...                                ...                      ...
# 94374                              4.0                      1.0
# 94375                             12.0                      4.0
# 94376                             12.0                      0.0
# 94377                             12.0                      2.0
# 94378                              3.0                      3.0
#
#        Seat_Comfort Legroom  Seat_Class Legroom
# 0                       6.0                 0.0
# 1                       2.0                 2.0
# 2                      10.0                 0.0
# 3                       9.0                 3.0
# 4                      12.0                 4.0
# ...                     ...                 ...
# 94374                   4.0                 4.0
# 94375                  12.0                 3.0
# 94376                   8.0                 0.0
# 94377                   8.0                 4.0
# 94378                  12.0                 4.0
#
# [94379 rows x 36 columns]

# %%
# Consider: 'Onboard_Wifi_Service', 'Onboard_Entertainment'
D = ['Onboard_Wifi_Service', 'Onboard_Entertainment']
train_data_ABCD = create_interaction_features(train_data_ABC, D)
test_data_ABCD = create_interaction_features(test_data_ABC, D)

# %%
train_data_ABCD
# Out:
#              ID  Gender  Customer_Type   Age  Type_Travel  Travel_Class  \
# 0      98800001     0.0            1.0  52.0          0.0             0
# 1      98800002     1.0            1.0  48.0          1.0             1
# 2      98800003     0.0            1.0  43.0          0.0             0
# 3      98800004     0.0            1.0  44.0          0.0             0
# 4      98800005     0.0            1.0  50.0          0.0             0
# ...         ...     ...            ...   ...          ...           ...
# 94374  98894375     1.0            1.0  32.0          0.0             0
# 94375  98894376     1.0            1.0  44.0          0.0             0
# 94376  98894377     1.0            1.0  63.0          0.0             0
# 94377  98894378     1.0            1.0  16.0          1.0             1
# 94378  98894379     1.0            1.0  54.0          0.0             1
#
#        Travel_Distance  Departure_Delay_in_Mins  Arrival_Delay_in_Mins  \
# 0                  272                      0.0                    5.0
# 1                 2200                      9.0                    0.0
# 2                 1061                     77.0                  119.0
# 3                  780                     13.0                   18.0
# 4                 1981                      0.0                    0.0
# ...                ...                      ...                    ...
# 94374             1357                     83.0                  125.0
# 94375              592                      5.0                   11.0
# 94376             2794                      0.0                    0.0
# 94377             2744                      0.0                    0.0
# 94378             2107                     28.0                   28.0
#
#        Seat_Comfort  ...  Online_Support Ease_of_Online_Booking  \
# 0               2.0  ...                                    6.0
# 1               1.0  ...                                   16.0
# 2               2.0  ...                                   25.0
# 3               3.0  ...                                    9.0
# 4               3.0  ...                                   20.0
# ...             ...  ...                                    ...
# 94374           1.0  ...                                    1.0
# 94375           4.0  ...                                   15.0
# 94376           2.0  ...                                   16.0
# 94377           2.0  ...                                   16.0
# 94378           3.0  ...                                    9.0
#
#        Online_Support Onboard_Service  Online_Support Online_Boarding  \
# 0                                 6.0                             3.0
# 1                                20.0                            16.0
# 2                                25.0                            25.0
# 3                                 9.0                             9.0
# 4                                20.0                            20.0
# ...                               ...                             ...
# 94374                             4.0                             1.0
# 94375                            15.0                            20.0
# 94376                            16.0                            12.0
# 94377                            12.0                            16.0
# 94378                             3.0                             9.0
#
#        Ease_of_Online_Booking Onboard_Service  \
# 0                                         4.0
# 1                                        20.0
# 2                                        25.0
# 3                                         9.0
# 4                                        16.0
# ...                                       ...
# 94374                                     4.0
# 94375                                     9.0
# 94376                                    16.0
# 94377                                    12.0
# 94378                                     3.0
#
#        Ease_of_Online_Booking Online_Boarding  \
# 0                                         2.0
# 1                                        16.0
# 2                                        25.0
# 3                                         9.0
# 4                                        16.0
# ...                                       ...
# 94374                                     1.0
# 94375                                    12.0
# 94376                                    12.0
# 94377                                    16.0
# 94378                                     9.0
#
#        Onboard_Service Online_Boarding  Seat_Comfort Seat_Class  \
# 0                                  2.0                      0.0
# 1                                 20.0                      1.0
# 2                                 25.0                      0.0
# 3                                  9.0                      3.0
# 4                                 16.0                      3.0
# ...                                ...                      ...
# 94374                              4.0                      1.0
# 94375                             12.0                      4.0
# 94376                             12.0                      0.0
# 94377                             12.0                      2.0
# 94378                              3.0                      3.0
#
#        Seat_Comfort Legroom  Seat_Class Legroom  \
# 0                       6.0                 0.0
# 1                       2.0                 2.0
# 2                      10.0                 0.0
# 3                       9.0                 3.0
# 4                      12.0                 4.0
# ...                     ...                 ...
# 94374                   4.0                 4.0
# 94375                  12.0                 3.0
# 94376                   8.0                 0.0
# 94377                   8.0                 4.0
# 94378                  12.0                 4.0
#
#        Onboard_Wifi_Service Onboard_Entertainment
# 0                                             8.0
# 1                                             4.0
# 2                                             8.0
# 3                                             6.0
# 4                                             8.0
# ...                                           ...
# 94374                                         1.0
# 94375                                        10.0
# 94376                                        20.0
# 94377                                         8.0
# 94378                                         9.0
#
# [94379 rows x 37 columns]

# %%
# Consider: 'Baggage_Handling', 'CheckIn_Service'
E = ['Baggage_Handling', 'CheckIn_Service']
train_data_ABCDE = create_interaction_features(train_data_ABCD, E)
test_data_ABCDE = create_interaction_features(test_data_ABCD, E)

# %%
train_data_ABCDE.shape
# Out:
# (94379, 38)

# %%
# Consider: 'Gender', 'Customer_Type', 'Age', 'Type_Travel'
F = ['Gender', 'Customer_Type', 'Age', 'Type_Travel']
train_data_ABCDEF = create_interaction_features(train_data_ABCDE, F)
test_data_ABCDEF = create_interaction_features(test_data_ABCDE, F)
train_data_ABCDEF.shape
# Out:
# (94379, 44)

# %%
train_data_ABCDEF.to_csv('X_train_wFE.csv', index=False)
test_data_ABCDEF.to_csv('X_test_wFE.csv', index=False)

# %%
pd.read_csv('X_train_wFE.csv')
# Out:
#              ID  Gender  Customer_Type   Age  Type_Travel  Travel_Class  \
# 0      98800001     0.0            1.0  52.0          0.0             0
# 1      98800002     1.0            1.0  48.0          1.0             1
# 2      98800003     0.0            1.0  43.0          0.0             0
# 3      98800004     0.0            1.0  44.0          0.0             0
# 4      98800005     0.0            1.0  50.0          0.0             0
# ...         ...     ...            ...   ...          ...           ...
# 94374  98894375     1.0            1.0  32.0          0.0             0
# 94375  98894376     1.0            1.0  44.0          0.0             0
# 94376  98894377     1.0            1.0  63.0          0.0             0
# 94377  98894378     1.0            1.0  16.0          1.0             1
# 94378  98894379     1.0            1.0  54.0          0.0             1
#
#        Travel_Distance  Departure_Delay_in_Mins  Arrival_Delay_in_Mins  \
# 0                  272                      0.0                    5.0
# 1                 2200                      9.0                    0.0
# 2                 1061                     77.0                  119.0
# 3                  780                     13.0                   18.0
# 4                 1981                      0.0                    0.0
# ...                ...                      ...                    ...
# 94374             1357                     83.0                  125.0
# 94375              592                      5.0                   11.0
# 94376             2794                      0.0                    0.0
# 94377             2744                      0.0                    0.0
# 94378             2107                     28.0                   28.0
#
#        Seat_Comfort  ...  Seat_Comfort Legroom  Seat_Class Legroom  \
# 0               2.0  ...                   6.0                 0.0
# 1               1.0  ...                   2.0                 2.0
# 2               2.0  ...                  10.0                 0.0
# 3               3.0  ...                   9.0                 3.0
# 4               3.0  ...                  12.0                 4.0
# ...             ...  ...                   ...                 ...
# 94374           1.0  ...                   4.0                 4.0
# 94375           4.0  ...                  12.0                 3.0
# 94376           2.0  ...                   8.0                 0.0
# 94377           2.0  ...                   8.0                 4.0
# 94378           3.0  ...                  12.0                 4.0
#
#        Onboard_Wifi_Service Onboard_Entertainment  \
# 0                                             8.0
# 1                                             4.0
# 2                                             8.0
# 3                                             6.0
# 4                                             8.0
# ...                                           ...
# 94374                                         1.0
# 94375                                        10.0
# 94376                                        20.0
# 94377                                         8.0
# 94378                                         9.0
#
#        Baggage_Handling CheckIn_Service  Gender Customer_Type  Gender Age  \
# 0                                   8.0                   0.0         0.0
# 1                                   2.0                   1.0        48.0
# 2                                  20.0                   0.0         0.0
# 3                                  12.0                   0.0         0.0
# 4                                  16.0                   0.0         0.0
# ...                                 ...                   ...         ...
# 94374                               8.0                   1.0        32.0
# 94375                              12.0                   1.0        44.0
# 94376                              12.0                   1.0        63.0
# 94377                              16.0                   1.0        16.0
# 94378                               4.0                   1.0        54.0
#
#        Gender Type_Travel  Customer_Type Age  Customer_Type Type_Travel  \
# 0                     0.0               52.0                        0.0
# 1                     1.0               48.0                        1.0
# 2                     0.0               43.0                        0.0
# 3                     0.0               44.0                        0.0
# 4                     0.0               50.0                        0.0
# ...                   ...                ...                        ...
# 94374                 0.0               32.0                        0.0
# 94375                 0.0               44.0                        0.0
# 94376                 0.0               63.0                        0.0
# 94377                 1.0               16.0                        1.0
# 94378                 0.0               54.0                        0.0
#
#        Age Type_Travel
# 0                  0.0
# 1                 48.0
# 2                  0.0
# 3                  0.0
# 4                  0.0
# ...                ...
# 94374              0.0
# 94375              0.0
# 94376              0.0
# 94377             16.0
# 94378              0.0
#
# [94379 rows x 44 columns]
